# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 1000) 
y = 0.5 * (abs(x + 1) - abs(x - 1))
sigma = 1e-12
y1 = 0.5 * (np.sqrt((x + 1)**2) - np.sqrt((x - 1)**2))
print(np.mean(y-y1))
plt.plot(x, y)
plt.plot(x, y1)
# Out:
# 0.0

# %%
im = Image.open('images/lenna_edge.png')
im1 = Image.open('images/test_training/test_train_10_1sstep.jpg')

im = np.array(im)/255
im1 = np.array(im1)/255
print(im.shape, im1.shape)
print(f'im_true range:{im.min()}~{im.max()}')
print(f'im_train range:{im1.min()}~{im1.max()}')
error = np.mean(np.abs(im-im1))
print(error)

im_ = im.reshape(-1)
im1_ = im1.reshape(-1)
im_.sort()
im1_.sort()
plt.plot(im_)
plt.plot(im1_)
# Out:
# (128, 128, 3) (128, 128, 3)
# im_true range:0.0~1.0
# im_train range:0.0~1.0
# 0.4635153377757353
