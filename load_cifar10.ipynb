# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import os
from general import load_cifar10

# %%
path = '../dataset/cifar-10-batches-py/'
datasets, labels = load_cifar10(path=path)
im1 = datasets[130].reshape(3, 32, 32).transpose(1,2,0)
plt.imshow(im1)
# Out:
# ['data_batch_3', 'data_batch_4', 'data_batch_5', 'data_batch_2', 'data_batch_1']
# datasets shape: (50000, 3072), labels shape: (50000,)

# %%
labels_ = np.array(labels)
labels_.sort()
plt.plot(labels_)
